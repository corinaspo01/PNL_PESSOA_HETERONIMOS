# %% [markdown]
# <a href="https://colab.research.google.com/github/corinasposito/PNL_PESSOA_HETERONIMOS/blob/main/PYSENTIMIENTO_PESSOA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk matplotlib

# %%
pip install pysentimiento
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 23.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.1 MB/s eta 0:00:00
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171033 sha256=7a7f83a84d3be7a7c6805dd82f647643ca291afb3473d605c2724712a0d2e335
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# ...

# %%
pip install --upgrade pysentimiento

# %%
pip install transformers[torch]

# %%
import nltk
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt

# %%
from urllib import request

def leer_url(url):
    response = request.urlopen(url)
    text = response.read().decode('utf-8')
    return text

url = "https://raw.githubusercontent.com/corinaspo01/tfm1/main/campos.txt?token=GHSAT0AAAAAACGIXBSE5FEAZJKMS5URKVUWZHAOGBA" #el link sale del raw de github ---> https://github.com/corinaspo01/tfm1/blob/main/campos.txt
texto = leer_url(url)
# print(texto)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#TOKENIZAR FRASES

from nltk import sent_tokenize

def tokenizar_frases(texto):
    tokens = sent_tokenize(texto)
    return tokens
sent_token = tokenizar_frases(texto)
print (sent_token)
# Out:
# ['¡Tan poco heráldica la vida!', '¡Tan sin tronos y oropeles cotidianos!', '¡Tan sentirse desnuda, tan hueca de sí misma!', 'Ahogadme, oh ruido de la acción, en el sonido de vuestros\nespacios oceánicos!', 'Benditos seáis, coches, trenes y vagones,\nrespirar regular de fábricas y temblorosos motores atronando\ncon vuestra crónica!', '¡Sí, benditos seáis, por ocultarme!', 'Vosotros ocultáis el real y entero silencio de la Hora.', 'Desnudáis de rumores al misterio\nque casi grita en mí, que casi llora,\nque duerme en vuestro férreo balanceo.', 'Llevadme lejos de saber qué vida siento.', 'Llenad con lo banal y material mi oído que es vuestro.', 'Esa vida que vivo - ¡oh!', '- es la vida que miento.', 'Tengo solo eso que...; y solo quiero lo que tener no puedo.', 'Soñar un sueño es perder otro.', 'Triste contemplo el puente, tan pesado y en calma...\nCada sueño es existencia de otro sueño,\n¡oh eterna desterrada en ti misma, oh mi alma!', 'Siento en mi cuerpo, más conscientemente,\nel rod
# ...

# %%
from pysentimiento import create_analyzer

# %%
analyzer = create_analyzer(task="sentiment", lang="es")

# Variables para contar los sentimientos
total_positivo = 0
total_negativo = 0
total_neutro = 0

# Iterar sobre cada frase y analizar su sentimiento
for sentence in sent_token:
    sentiment = analyzer.predict(sentence)


    # Contar los sentimientos
    if sentiment.output == "POS":
        total_positivo += 1
    elif sentiment.output == "NEG":
        total_negativo += 1
    elif sentiment.output == "NEU":
        total_neutro += 1
# Out:
# config.json:   0%|          | 0.00/925 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/435M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]

# %%
# Calcular la proporción de sentimientos
total_frases = len(sent_token)
proporcion_positivo = total_positivo / total_frases
proporcion_negativo = total_negativo / total_frases
proporcion_neutro = total_neutro / total_frases

# Imprimir las proporciones
print("Proporción de sentimientos:")
print(f"Positivo: {proporcion_positivo:.2f}")
print(f"Negativo: {proporcion_negativo:.2f}")
print(f"Neutro: {proporcion_neutro:.2f}")
# Out:
# Proporción de sentimientos:
# Positivo: 0.15
# Negativo: 0.38
# Neutro: 0.46

# %%
# Crear un analizador de emociones
emotion_analyzer = create_analyzer(task="emotion", lang="es")

# Variables para contar los sentimientos
total_anger = 0
total_surprise = 0
total_fear = 0
total_disgust = 0
total_joy = 0
total_others = 0
total_sadness = 0

# Iterar sobre cada frase y analizar su sentimiento
for sentence in sent_token:
    sentiment = emotion_analyzer.predict(sentence)

    # Contar los sentimientos
    if sentiment.output == "anger":
        total_anger += 1
    elif sentiment.output == "surprise":
        total_surprise += 1
    elif sentiment.output == "fear":
        total_fear += 1
    elif sentiment.output == "disgust":
        total_disgust += 1
    elif sentiment.output == "joy":
        total_joy += 1
    elif sentiment.output == "others":
        total_others += 1
    elif sentiment.output == "sadness":
        total_sadness += 1

total_frases = len(sent_token)
proporcion_anger = total_anger / total_frases
proporcion_surprise = total_surprise / total_frases
proporcion_fear = total_fear / total_frases
proporcion_disgust = total_disgust / total_frases
proporcion_joy = total_joy / total_frases
proporcion_others = total_others / total_frases
proporcion_sadness = total_sadness / total_frases

# Imprimir las proporciones
print("Proporción de sentimientos:")
print(f"Anger: {proporcion_anger:.2f}")
print(f"Surprise: {proporcion_surprise:.2f}")
print(f"Fear: {proporcion_fear:.2f}")
print(f"Disgust: {proporcion_disgust:.2f}")
print(f"Joy: {proporcion_joy:.2f}")
print(f"Others: {proporcion_others:.2f}")
print(f"Sadness: {proporcion_sadness:.2f}")
# Out:
# config.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/435M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# Proporción de sentimientos:
# Anger: 0.07
# Surprise: 0.02
# Fear: 0.01
# Disgust: 0.00
# Joy: 0.15
# Others: 0.60
# Sadness: 0.15

# %%
# Crear un analizador de discurso de odio
hate_speech_analyzer = create_analyzer(task="hate_speech", lang="es")

# Variables para contar los sentimientos
total_hateful = 0
total_targeted = 0
total_aggressive = 0

# Iterar sobre cada frase y analizar su sentimiento
for sentence in sent_token:
    sentiment = hate_speech_analyzer.predict(sentence)

    # Contar los sentimientos
    if sentiment.output == "hateful":
        total_hateful += 1
    elif sentiment.output == "targeted":
        total_targeted += 1
    elif sentiment.output == "aggressive":
        total_aggressive += 1

total_frases = len(sent_token)
proporcion_hateful = total_hateful / total_frases
proporcion_targeted = total_targeted / total_frases
proporcion_aggressive = total_aggressive / total_frases

# Imprimir las proporciones
print("Proporción de discurso de odio:")
print(f"Hateful: {proporcion_hateful:.2f}")
print(f"Targeted: {proporcion_targeted:.2f}")
print(f"Aggressive: {proporcion_aggressive:.2f}")
# Out:
# config.json:   0%|          | 0.00/956 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/435M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# Proporción de discurso de odio:
# Hateful: 0.00
# Targeted: 0.00
# Aggressive: 0.00
